# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from monitor_metrics import metric_plotter

# %%
# runID = "c481a804abcf441aaaf23e2a5870c98f" # reduce to 1x1 archi
# expID = "3"

# runID = "bcbd5e06e04c47d28ff64658053ccb93" # flatten when 3x3 archi
expID = "3"

# runID = "b57f060c17344293ae4a49d53776fec2" # no pooling archi]
# runID = "2ea0956f9e9d4bf9a6e9eb01540397e5" # 20 epoch no pooling

runID = "1393b405d5d34849b7bf783eba004e42" # more channels
plotter = metric_plotter(expID, runID)

# %%
plotter.plot_metric("loss", verbose=1)
# Out:
# Training:  [0.9355679750442505, 0.760328471660614, 0.7132015228271484, 0.6941327452659607, 0.6813309192657471, 0.6719257831573486, 0.6635182499885559, 0.657312273979187, 0.6520116329193115, 0.6468371152877808]
# Validation:  [0.8111777305603027, 0.7219469547271729, 0.6940874457359314, 0.6805252432823181, 0.6759360432624817, 0.6752334237098694, 0.6742507219314575, 0.697496771812439, 0.6632745265960693, 0.6659824252128601]

# %%
plotter.plot_metric("categorical_accuracy", verbose=1)
# Out:
# Training:  [0.561349093914032, 0.6749109029769897, 0.7013909220695496, 0.7111872434616089, 0.7172254323959351, 0.7211945652961731, 0.7251254320144653, 0.7275163531303406, 0.7298290729522705, 0.7316545248031616]
# Validation:  [0.6426849961280823, 0.699180006980896, 0.7148550152778625, 0.7182199954986572, 0.7214850187301636, 0.7234699726104736, 0.7212849855422974, 0.7221999764442444, 0.7290099859237671, 0.7254850268363953]
