# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from monitor_metrics import metric_plotter

# %%
# runID = "c481a804abcf441aaaf23e2a5870c98f" # reduce to 1x1 archi
# expID = "3"

# runID = "bcbd5e06e04c47d28ff64658053ccb93" # flatten when 3x3 archi
# expID = "3"

# runID = "b57f060c17344293ae4a49d53776fec2" # no pooling archi]
# runID = "2ea0956f9e9d4bf9a6e9eb01540397e5" # 20 epoch no pooling

# runID = "1393b405d5d34849b7bf783eba004e42" # more channels

# expID = "4"
# runID = "5aee19d636a841aaabe0496c3dd67d1f"
# runID = "8d0dd184fedc45c8bb49de804f016346"


# custom loop 4 epoch:
# expID = "5"
# runID = "28785ab4a01a48eb97bcc6c8ac231ba5"


# 4 epoch similar no drop:
# expID = "2"
# runID = "3110974a729743b7aeddf2a959aeca28"


# previous best:
expID = "7" 
runID = "deb4d6b122414f3cae0a4d0927b0765c" # 5e continue 4d9 # THESE ARE THE BEST


# RUNS WITH STANDARDISATION:
# expID = "9"
# runID = "4713ecd0290f43409d1670b93529ae1b" # full 0 dropout
# runID = "034f040de8fa478c9e07782d5fe8112c" # reduced (80k) 0 drop
# runID = "4d9e38473bb9485ca8693f85dd7b4bce" # full 0.2 drop
# runID = "cf49d9f90c444738ad7e00861675227a" # full 0.3 drop
# runID = "c7698d28cb5045b1946fb7b6b510f9fc" # full 0.5 drop
# runID = "beb35a4fd532498b9e3a32894fe3c87f" # red 0.2 drop

# NEW RUNS (max clipped)
expID = "10"
runID = "6d16fd8421b544dbab84201afcb315ed" #5epochs
runID = "6daf836007814378b081099af6f7b671" # extend 6d16 5 epochs
# runID = "78d0332044f14ce68dea959663d8ffcb" # extend 5 extend 5 

# MASS VARS
# expID = "11"
# runID = "8875dfd5a0254687b2c2f0757d82f107"

# runID = "322cf70112c14fb486ac4e13ddc97fe4" # 5 epoch repeat

expID = "10"
runID ="a6aba6ad2dee4b77a4dad8b03c8f06c6" # trying HPS vars

expID = "2" # updated with pi0
runID = "259020279434462e9ceaf94ca7ff4585"
runID = "0044e2b9c698422e9a9518543b14824c" # ext 5e
runID = "370ca5c69fa7466dab8018d9dfa46a82" # ext 5 ext 5
# runID = "3f1c88db67904023b901b89031dc4e8a" # ext 5 ext 5 ext 5
runID = "3024f126b7b64fdebd98d903616141a2" # dr 



# expID="3" # dm runs
# runID = "278ccbf28aca417bb245ec6cc0e7864d" # all hps vars + 250b
# runID="50f9fa4003e5486180352cf052742848" # hps b50
# runID = "943c690502784037a9f939fd24a244c9" # b50 5e5e
# expID = "4"
# runID = "146c138a852b4fd1b6521e1c94ddb7af" # eta only

# expID = "5" # momentum only
# runID = "82e8ff7401aa4745bab6e909f4835635"

# expID="3" # dm runs
# runID = "278ccbf28aca417bb245ec6cc0e7864d" # all hps vars + 250b
# runID="50f9fa4003e5486180352cf052742848" # hps b50
# runID = "943c690502784037a9f939fd24a244c9" # b50 5e5e

plotter = metric_plotter(expID, runID)

# %%
plotter.plot_metric("loss", verbose=1, save=1)
# Out:
# Training:  [0.0003945698554161936, 0.00027415502700023353, 0.0002562748559284955, 0.00024709515855647624, 0.00024156020663212985]
# Validation:  [0.0002921948325820267, 0.0002651645918376744, 0.00025261452537961304, 0.0002456257934682071, 0.0002422683610348031]

# %%
plotter.plot_metric("DM_accuracy", verbose=1, save=1)
# Out:
# Note: Model training was started from 50f9fa4003e5486180352cf052742848 (3)
# Training:  [0.7435562610626221, 0.7784932851791382, 0.7857959270477295, 0.7897617816925049, 0.7923418283462524, 0.7941779494285583, 0.7955710291862488, 0.7967534065246582, 0.7977185249328613, 0.7985438108444214]
# Validation:  [0.7784906625747681, 0.7883627414703369, 0.7925906777381897, 0.794742226600647, 0.796339750289917, 0.7967230081558228, 0.7985621094703674, 0.7991012334823608, 0.7999584078788757, 0.8006726503372192]

# %%
plotter.plot_metric("MAE_eta", verbose=1, save=1)
# Out:
# Note: Model training was started from 0044e2b9c698422e9a9518543b14824c (2)
# Which was started from 259020279434462e9ceaf94ca7ff4585 (2)
# Training:  [0.032319534569978714, 0.019074102863669395, 0.01784679852426052, 0.017183728516101837, 0.01676763780415058, 0.01652945764362812, 0.016287624835968018, 0.01613369770348072, 0.016000919044017792, 0.015879835933446884, 0.015816228464245796, 0.015682265162467957, 0.015600298531353474, 0.015525320544838905, 0.015456578694283962]
# Validation:  [0.02073337323963642, 0.018445570021867752, 0.017554152756929398, 0.017223527655005455, 0.016725530847907066, 0.016370989382267, 0.016487330198287964, 0.01619722694158554, 0.01600814051926136, 0.01592986099421978, 0.015796218067407608, 0.015848927199840546, 0.015781395137310028, 0.01567354053258896, 0.015537322498857975]

# %%
plotter.plot_metric("MAE_phi", verbose=1, save=1)
# Out:
# Note: Model training was started from 0044e2b9c698422e9a9518543b14824c (2)
# Which was started from 259020279434462e9ceaf94ca7ff4585 (2)
# Training:  [0.08038367331027985, 0.05924083665013313, 0.05547661334276199, 0.05349528044462204, 0.052296046167612076, 0.05146540328860283, 0.05075976997613907, 0.05020040273666382, 0.04973430559039116, 0.04936649650335312, 0.04910484328866005, 0.04882080852985382, 0.0486074835062027, 0.04841288551688194, 0.048232901841402054]
# Validation:  [0.0635455846786499, 0.05769231915473938, 0.054615337401628494, 0.05294041708111763, 0.05202821269631386, 0.05127444118261337, 0.0507986843585968, 0.050279222428798676, 0.04984428733587265, 0.04958172142505646, 0.04943116381764412, 0.0491551011800766, 0.04905383288860321, 0.04909100756049156, 0.04874342679977417]
