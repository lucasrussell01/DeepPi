# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from monitor_metrics import metric_plotter

# %%
# runID = "c481a804abcf441aaaf23e2a5870c98f" # reduce to 1x1 archi
# expID = "3"

# runID = "bcbd5e06e04c47d28ff64658053ccb93" # flatten when 3x3 archi
# expID = "3"

# runID = "b57f060c17344293ae4a49d53776fec2" # no pooling archi]
# runID = "2ea0956f9e9d4bf9a6e9eb01540397e5" # 20 epoch no pooling

# runID = "1393b405d5d34849b7bf783eba004e42" # more channels

# expID = "4"
# runID = "5aee19d636a841aaabe0496c3dd67d1f"
# runID = "8d0dd184fedc45c8bb49de804f016346"


# custom loop 4 epoch:
# expID = "5"
# runID = "28785ab4a01a48eb97bcc6c8ac231ba5"


# 4 epoch similar no drop:
# expID = "2"
# runID = "3110974a729743b7aeddf2a959aeca28"


# previous best:
expID = "7" 
runID = "deb4d6b122414f3cae0a4d0927b0765c" # 5e continue 4d9 # THESE ARE THE BEST


# RUNS WITH STANDARDISATION:
# expID = "9"
# runID = "4713ecd0290f43409d1670b93529ae1b" # full 0 dropout
# runID = "034f040de8fa478c9e07782d5fe8112c" # reduced (80k) 0 drop
# runID = "4d9e38473bb9485ca8693f85dd7b4bce" # full 0.2 drop
# runID = "cf49d9f90c444738ad7e00861675227a" # full 0.3 drop
# runID = "c7698d28cb5045b1946fb7b6b510f9fc" # full 0.5 drop
# runID = "beb35a4fd532498b9e3a32894fe3c87f" # red 0.2 drop

# NEW RUNS (max clipped)
expID = "10"
runID = "6d16fd8421b544dbab84201afcb315ed" #5epochs
runID = "6daf836007814378b081099af6f7b671" # extend 6d16 5 epochs
# runID = "78d0332044f14ce68dea959663d8ffcb" # extend 5 extend 5 

# MASS VARS
# expID = "11"
# runID = "8875dfd5a0254687b2c2f0757d82f107"

# runID = "322cf70112c14fb486ac4e13ddc97fe4" # 5 epoch repeat

expID = "10"
runID ="a6aba6ad2dee4b77a4dad8b03c8f06c6" # trying HPS vars
plotter = metric_plotter(expID, runID)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 55>()
#      53 expID = "10"
#      54 runID ="a6aba6ad2dee4b77a4dad8b03c8f06c6" # trying HPS vars
# ---> 55 plotter = metric_plotter(expID, runID)
#
# File ~/DeepPi/Evaluation/notebooks/../python/monitor_metrics.py:19, in metric_plotter.__init__(self, expID, runID)
#      17 self.path_to_mlflow = "../../Training/python/mlruns/"
#      18 self.path_to_metrics = self.path_to_mlflow + self.expID + "/" + self.runID + "/metrics"
# ---> 19 with open(f'{self.path_to_mlflow}{self.expID}/{self.runID}/artifacts/input_cfg/hydra/config.yaml') as file:
#      20     self.cfg = yaml.full_load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Training/python/mlruns/10/a6aba6ad2dee4b77a4dad8b03c8f06c6/artifacts/input_cfg/hydra/config.yaml'

# %%
plotter.plot_metric("DM_loss", verbose=1)
# Out:
# Note: Model training was started from 6d16fd8421b544dbab84201afcb315ed (10)
# Training:  [0.7181223630905151, 0.6126795411109924, 0.5878331661224365, 0.5741859078407288, 0.5647760629653931, 0.5572905540466309, 0.5515612363815308, 0.5469995141029358, 0.5434367656707764, 0.5404541492462158]
# Validation:  [0.6224401593208313, 0.5863717198371887, 0.5695472359657288, 0.5642818808555603, 0.5523387789726257, 0.546116292476654, 0.548865795135498, 0.5403451919555664, 0.5327858328819275, 0.5307528376579285]

# %%
plotter.plot_metric("DM_accuracy", verbose=1)
# Out:
# Note: Model training was started from 6d16fd8421b544dbab84201afcb315ed (10)
# Training:  [0.6919385194778442, 0.742630660533905, 0.7539625763893127, 0.759696364402771, 0.7634942531585693, 0.7665038108825684, 0.7688348889350891, 0.7707267999649048, 0.7721518874168396, 0.7733929753303528]
# Validation:  [0.7388530373573303, 0.7550806999206543, 0.7618494033813477, 0.7655879259109497, 0.7684421539306641, 0.770485520362854, 0.7698433995246887, 0.7733180522918701, 0.7756891846656799, 0.7765361666679382]
