# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from monitor_metrics import metric_plotter

# %%
expID = "7" #New centering convention 
runID= "43aae5258b854209a4db74a88809cbf3" # 5e
runID = "72c3f9b78b1a43d78fdddfba9f31a42c" # 15e
runID = "9c730c7964134567ad2a6cfd7e5c81cb" # 20e

# expID = "4" # eta only
# runID = "ed352f032c6b4e0eaecc9d944ac58e6d" #10e
# runID = "fb7ea06f127a4e76a329debd9dd052ee" #15e

expID = "8" # phi only
# runID = "48ebb48df97c46b7850a415ed8c52633" #5e
runID = "8887bd61d4d54003b6c9e5594aed7830" #10e

expID = "9" # egamma centre
runID = "109fcf637c524c04946d339dceb2e984" # 5e
runID = "368a2efe83b34cb49bc62067f7133cd1" # 10e

plotter = metric_plotter(expID, runID)

# %%
plotter.plot_metric("loss", verbose=1)
# Out:
# Note: Model training was started from 109fcf637c524c04946d339dceb2e984 (9)
# Training:  [0.07968936860561371, 0.059474505484104156, 0.05546443909406662, 0.05350537225604057, 0.05221663787961006, 0.0513453409075737, 0.05067915469408035, 0.050182145088911057, 0.049752891063690186, 0.049411844462156296]
# Validation:  [0.06436346471309662, 0.05744908004999161, 0.054660554975271225, 0.05315204709768295, 0.05196288973093033, 0.05127521976828575, 0.050879303365945816, 0.05042150989174843, 0.05013512074947357, 0.0498189702630043]

# %%
plotter.plot_metric("MAE_eta", verbose=1)
# Out:
# Note: Model training was started from 109fcf637c524c04946d339dceb2e984 (9)
# Training:  [0.4049837291240692, 0.3997819125652313, 0.40761327743530273, 0.4185659885406494, 0.4208458662033081, 0.41384509205818176, 0.41237521171569824, 0.4015894830226898, 0.39622390270233154, 0.385985791683197]
# Validation:  [0.3976137042045593, 0.3983686566352844, 0.41433244943618774, 0.42349645495414734, 0.42110565304756165, 0.4125080108642578, 0.40840238332748413, 0.3949425220489502, 0.38878658413887024, 0.3777046501636505]
