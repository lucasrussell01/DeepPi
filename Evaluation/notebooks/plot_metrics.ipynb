# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from monitor_metrics import metric_plotter

# %%
# runID = "c481a804abcf441aaaf23e2a5870c98f" # reduce to 1x1 archi
# expID = "3"

# runID = "bcbd5e06e04c47d28ff64658053ccb93" # flatten when 3x3 archi
# expID = "3"

# runID = "b57f060c17344293ae4a49d53776fec2" # no pooling archi]
# runID = "2ea0956f9e9d4bf9a6e9eb01540397e5" # 20 epoch no pooling

# runID = "1393b405d5d34849b7bf783eba004e42" # more channels

expID = "4"
runID = "5aee19d636a841aaabe0496c3dd67d1f"
# runID = "8d0dd184fedc45c8bb49de804f016346"


# custom loop 4 epoch:
# expID = "5"
# runID = "28785ab4a01a48eb97bcc6c8ac231ba5"


# 4 epoch similar no drop:
# expID = "2"
# runID = "3110974a729743b7aeddf2a959aeca28"
plotter = metric_plotter(expID, runID)

# %%
plotter.plot_metric("loss", verbose=1)
# Out:
# Training:  [0.7201787829399109, 0.622378408908844, 0.5975337624549866, 0.583516538143158, 0.5736163258552551]
# Validation:  [0.6363835334777832, 0.6041831374168396, 0.5937070250511169, 0.591345489025116, 0.5758836269378662]

# %%
plotter.plot_metric("categorical_accuracy", verbose=1)
# Out:
# Training:  [0.6908307671546936, 0.7379704713821411, 0.7491662502288818, 0.7554795145988464, 0.7597085237503052]
# Validation:  [0.7340676188468933, 0.7465605735778809, 0.7515718340873718, 0.7526873350143433, 0.7583732604980469]
