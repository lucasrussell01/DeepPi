# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from monitor_metrics import metric_plotter

# %%
expID = "c481a804abcf441aaaf23e2a5870c98f"
runID = "3"

plotter = metric_plotter(runID, expID)

# %%
plotter.plot_metric("loss")
# Out:
# Training:  ['1.0449241399765015', '0.9772226214408875', '0.955857515335083', '0.9259641766548157', '0.8842330574989319', '0.8299363851547241', '0.7685123682022095', '0.7364733219146729', '0.7194510698318481', '0.7060530185699463']
# Validation:  ['0.9891659617424011', '0.9704482555389404', '0.9460693597793579', '0.8971233367919922', '0.8564193844795227', '0.7858836054801941', '0.7404110431671143', '0.7185098528862', '0.7030467987060547', '0.6918935179710388']
