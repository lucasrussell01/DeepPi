# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from monitor_metrics import metric_plotter

# %%
# runID = "c481a804abcf441aaaf23e2a5870c98f" # reduce to 1x1 archi
# expID = "3"

# runID = "bcbd5e06e04c47d28ff64658053ccb93" # flatten when 3x3 archi
# expID = "3"

# runID = "b57f060c17344293ae4a49d53776fec2" # no pooling archi]
# runID = "2ea0956f9e9d4bf9a6e9eb01540397e5" # 20 epoch no pooling

# runID = "1393b405d5d34849b7bf783eba004e42" # more channels

# expID = "4"
# # runID = "5aee19d636a841aaabe0496c3dd67d1f"
# runID = "8d0dd184fedc45c8bb49de804f016346"


# # custom loop 4 epoch:
# expID = "5"
# runID = "28785ab4a01a48eb97bcc6c8ac231ba5"


# 18/08 batch runs
expID = "5"
runID = "21698cc7c2044578af4d045bafbc12a5" # 5 epoch 0 dropout
# runID = "4d938a098fbb46898a368928c05091f7" # same 5 epoch 0 dropout
# runID = "41abf0160ab243fdb16ab59801ef46c1" # 5 epoch 0.2 drop
# runID = "34fd40117d8141e5abf17f20fb162c49" # 10 epoch 0.2 drop


# expID = "7"
# runID = "50c0002e0f774272ac3c80cd65844838" # E only 0 dropout
# runID = "81033dc48821453d85862471fe26271a" # ABCD no dropout


# extend batch runs
expID = "7" 
# runID = "c25ee03e03e841108400e2b7b9e105e5" # 5e continue 216
runID = "deb4d6b122414f3cae0a4d0927b0765c" # 5e continue 4d9
# runID = "773eb2b17c174c708c36caf6d93e3df6" #10 e continue 216 

# runID = "71a531de46154f93a26f61a29c43c699" # 5e continue deb

# runID = "aba57d572437450b91a9f69e3a360136" #ABCD rep

# # larger batches:
# expID = "8"
# runID = "a22a422e3f6c4576b71ca2e153e8a727" #ABC
# runID = "a49c6b3b66e24fa9aaa102c0063572f8" #ABCD

# COMPARING WITH SAME VAL
# expID = "8"
# runID = "10f11a6313354c3e89e1ce620fbe80e0" # ABC Train + Val
# runID = "5a055285ce5045cb83acaf8516698a10" # ABCD Train, ABC Val Run 1
# runID = "505f5b117b764cc8acd3e22f06d8b19c" # ABCD Train, ABC Val Run 2

plotter = metric_plotter(expID, runID)

# %%
plotter.plot_metric("loss", verbose=1)
# Out:
# Note: Model training was started from 4d938a098fbb46898a368928c05091f7 (5)
# Training:  [0.7152935266494751, 0.6084498167037964, 0.587048351764679, 0.5749809741973877, 0.5667340755462646, 0.5603652596473694, 0.5553355813026428, 0.5513474345207214, 0.5478848814964294, 0.5449209213256836]
# Validation:  [0.6179206967353821, 0.5892395973205566, 0.5784432291984558, 0.5699265003204346, 0.5618331432342529, 0.5588765740394592, 0.561097264289856, 0.5508120656013489, 0.5506017208099365, 0.5459833145141602]

# %%
plotter.plot_metric("categorical_accuracy", verbose=1)
# Out:
# Note: Model training was started from 4d938a098fbb46898a368928c05091f7 (5)
# Training:  [0.6913682222366333, 0.7432722449302673, 0.7532132267951965, 0.7586579918861389, 0.7622119784355164, 0.7649107575416565, 0.7669572234153748, 0.7685034871101379, 0.7700207233428955, 0.7712637782096863]
# Validation:  [0.7383816838264465, 0.750659167766571, 0.7557633519172668, 0.759573221206665, 0.7633169293403625, 0.764936625957489, 0.7641986012458801, 0.7687633633613586, 0.7691253423690796, 0.7702535390853882]
