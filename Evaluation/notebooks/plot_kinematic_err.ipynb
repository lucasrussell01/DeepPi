# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from kinematic_pred_distrib import error_plotter

# %%
expID = "8"
runID = "de1bab4b3ee94495956c4d6bc3181387" # 5epoch k1k1

expID = "18"
runID = "aaa3d69a8c094222bdf0f711da1f4a3a" # MAE with HPS
runID = "35afcd416fa145ae98fadfde5a7bead7" # MAE without HPS
# runID = "0b6ca382a559444ab3f1eec670264dc3" # MAE*max with HPS
# runID = "22daef25916947f8b03d0322f35b5e77" # MAE*max w/out HPS
runID = "61fc06d17a7d43d0979b537821dc4ac7" #MAE/max w/oiut HPS
runID = "b34a88eeacb84558a3d3e6b53ecd1502" # MAE/max woth HPS # BEST SO FAR
# # runID = "28796f2c8eef4d8bac398f42b98be20d" # MAE batch size 250
# runID = "2246e1e3ac654e8888128d24148ce567" # MAE batch 250 + HPS
# # runID = "8231835e9116423aa07af9f8cc579bcd" # MSE batch 250 + HPS
# runID = "452982bc62904f08a2bea65faf3252f7" # MAE batch 250 + HPS + 200 veto

expID = "20"
runID = "bae17979b5c64b4590a3c6bb3d3e3116"
runID = "625bad1a8a504ce8aa3ab9e51b6cbc66" # eta-phi HUber loss
plotter = error_plotter(expID, runID)

# %%
plotter.compare_momentum()

# %%
plotter.compare_eta()
# Out:
# 0.004614209215851164

# %%
plotter.compare_phi()

# %%
plotter.compare_profile("phi")
# Out:
# [  0.    2.5   5.    7.5  10.   12.5  15.   17.5  20.   22.5  25.   27.5
#   30.   32.5  35.   37.5  40.   42.5  45.   47.5  50.   52.5  55.   57.5
#   60.   65.   70.   75.   80.   90.  100.  120.  140.  160. ]
# [  1.25   3.75   6.25   8.75  11.25  13.75  16.25  18.75  21.25  23.75
#   26.25  28.75  31.25  33.75  36.25  38.75  41.25  43.75  46.25  48.75
#   51.25  53.75  56.25  58.75  62.5   67.5   72.5   77.5   85.    95.
#  110.   130.   150.  ]

# %%
plotter.compare_profile("eta")
# Out:
# [  0.    2.5   5.    7.5  10.   12.5  15.   17.5  20.   22.5  25.   27.5
#   30.   32.5  35.   37.5  40.   42.5  45.   47.5  50.   52.5  55.   57.5
#   60.   65.   70.   75.   80.   90.  100.  120.  140.  160. ]
# [  1.25   3.75   6.25   8.75  11.25  13.75  16.25  18.75  21.25  23.75
#   26.25  28.75  31.25  33.75  36.25  38.75  41.25  43.75  46.25  48.75
#   51.25  53.75  56.25  58.75  62.5   67.5   72.5   77.5   85.    95.
#  110.   130.   150.  ]

# %%
plotter.plot_orig_releta(p_range=[80, 120])
# Out:
# P RANGE:  [80, 120]

# %%
plotter.plot_releta()
