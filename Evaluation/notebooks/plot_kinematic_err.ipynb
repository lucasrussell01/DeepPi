# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from kinematic_predictions import kin_pred

# Using New Centering Convention

# expID = "7" # eta-phi together
# runID= "43aae5258b854209a4db74a88809cbf3" # 5e
# runID = "72c3f9b78b1a43d78fdddfba9f31a42c" # 15e
# runID = "9c730c7964134567ad2a6cfd7e5c81cb" # 20e
# runID="ae560abb06ab4a2285fb7b11efa449ba" #25e
# runID="76f4d56b828b47d796acce35cfadfadc" #30e

expID = "4" #eta only
# runID = "2b58f417311b4c89921598bb3ab193fd" #5e
# runID = "ed352f032c6b4e0eaecc9d944ac58e6d" #10e
# runID = "fb7ea06f127a4e76a329debd9dd052ee" #15e
runID = "92b9e5e85ddf4a15ae3e2931df3bdd22" #20e

# expID = "8" # phi only
# runID = "48ebb48df97c46b7850a415ed8c52633" #5e
# runID = "8887bd61d4d54003b6c9e5594aed7830" #10e

plotter = kin_pred(expID, runID, DM=[1, 11], HPSDM=[1, 11], p_range=None)
# Out:
# Included True DMs: [1, 11]
# Included HPS DMs: [1, 11]
# Number of taus available: 531

# %%
plotter.momentum()

# %%
plotter.eta()

# %%
plotter.phi()

# %%
plotter.profile("phi")

# %%
plotter.profile("eta")

# %%
plotter.relphi()

# %%
plotter.releta()
