# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from confusion_matrix import cm_plotter

# %%
path_to_mlflow = "../../Training/python/mlruns/"
# expID = "3"
# runID = "c481a804abcf441aaaf23e2a5870c98f" # flatten when reduced to 1x1
# runID = "bcbd5e06e04c47d28ff64658053ccb93" # flatten when 3x3 archi
# runID = "b57f060c17344293ae4a49d53776fec2" # no pooling
# runID = "2ea0956f9e9d4bf9a6e9eb01540397e5" # 20 epoch no pooling
# runID = "1393b405d5d34849b7bf783eba004e42"

expID = "4"
runID = "5aee19d636a841aaabe0496c3dd67d1f"

plotter = cm_plotter(expID, runID)
# plotter.plot_raw_cm()
# Out:
# 2022-08-15 10:43:34.304137: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/hep/lcr119/conda/envs/tau-ml/envs/tau-ml/lib
# 2022-08-15 10:43:34.304185: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-08-15 10:43:34.304217: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (lx02.hep.ph.ic.ac.uk): /proc/driver/nvidia/version does not exist
# 2022-08-15 10:43:34.308576: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plotter.plot_cm()

# %%
plotter.plot_cm_oneP()

# %%
plotter.plot_cm_threeP()

# %%
plotter.plot_raw_cm_oneP()

# %%
plotter.plot_raw_cm_threeP()
