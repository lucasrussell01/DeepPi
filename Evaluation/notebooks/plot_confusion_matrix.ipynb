# %%
import sys
mod_path = "../python"
sys.path.append(mod_path)
from confusion_matrix import cm_plotter

# %%
path_to_mlflow = "../../Training/python/mlruns/"
expID = "3"
# runID = "c481a804abcf441aaaf23e2a5870c98f" # flatten when reduced to 1x1
runID = "bcbd5e06e04c47d28ff64658053ccb93" # flatten when 3x3 archi

plotter = cm_plotter(expID, runID)
# plotter.plot_raw_cm()

# %%
plotter.plot_cm()
# Out:
# [[0.82884856 0.16458073 0.00657071]
#  [0.17510797 0.77738516 0.04750687]
#  [0.0748538  0.61929825 0.30584795]]

# %%
plotter.plot_cm_oneP()
# Out:
# [[0.82565789 0.16710526 0.00723684]
#  [0.15801668 0.79425394 0.04772938]
#  [0.0748538  0.61929825 0.30584795]]

# %%
plotter.plot_cm_threeP()
# Out:
# [[0.83174224 0.16229117 0.00596659]
#  [0.26992288 0.68380463 0.04627249]
#  [0.         0.         0.        ]]

# %%
plotter.plot_raw_cm_oneP()
# Out:
# [[3265  576   32]
#  [1851 8487  498]
#  [ 316 2815 1013]]

# %%
plotter.plot_raw_cm_threeP()
# Out:
# [[3514  598   33]
#  [ 610 1314   78]
#  [   0    0    0]]
